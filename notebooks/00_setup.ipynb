# %%
# Load modules
import os                    # working directory 
import subprocess            # git clone
import sys                   # check Colab
from pathlib import Path     # paths


# Set working directory (w/ git clone)
IN_COLAB = 'google.colab' in sys.modules or Path('/content').exists()


if IN_COLAB:
    ROOT = Path('/content/dl_practice')
    if not ROOT.exists(): 
        subprocess.run(['git', 'clone', 'https://github.com/seungyong0223/dl_VAE_tutorial', str(ROOT) ])
    os.chdir(ROOT)
else:
    if '__file__' in dir(): 
        ROOT = Path(__file__).resolve().parents[1]
    else: 
        ROOT = Path.cwd()
    os.chdir(ROOT)
    
print(f"Working directory is {ROOT}")
# Out:
# Working directory is /content/dl_practice
